# %% [markdown]
# <a href="https://colab.research.google.com/github/Programmmer-X/STELLARIS-DNet/blob/main/notebooks/setup/colab_git_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Connecting to Git-Hub**

# %%
#STEP GH_1: CLONE YOUR REPO
# !git clone https://github.com/Programmmer-X/STELLARIS-DNet.git

# %cd /content/STELLARIS-DNet
# !rm -rf .gitmodules
# !git rm --cached -r STELLARIS-DNet
# !git reset
# Out:
# Cloning into 'STELLARIS-DNet'...
# remote: Enumerating objects: 221, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 221 (delta 16), reused 27 (delta 6), pack-reused 172 (from 1)
# Receiving objects: 100% (221/221), 1008.63 KiB | 7.58 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# /content/STELLARIS-DNet
# rm 'STELLARIS-DNet'

# %%
#STEP GH_2: CONFIGURE GIT
# !git config --global user.email "prajwal.sutar.0999@gmail.com"
# !git config --global user.name "Programmmer-X"

# %%
#STEP GH_3: AUTHENTICATION (REQUIRED FOR PUSH)

from getpass import getpass
TOKEN = getpass("Enter your GitHub PAT: ")

# !git remote set-url origin https://$TOKEN@github.com/Programmmer-X/STELLARIS-DNet.git
# Out:
# Enter your GitHub PAT: ··········

# %%
#STEP GH_4: TEST CONNECTION 1
with open("colab_test.txt", "w") as f:
    f.write("Colab connected successfully")

# %%
#STEP GH_4.1: PUSH TO GITHUB
# !git add .
# !git commit -m "Colab connection successful"
# !git pull origin main --rebase
# !git push origin main
# Out:
# [main b2f61e8] Colab connection successful
#  1 file changed, 1 insertion(+)
#  create mode 100644 colab_test.txt
# From https://github.com/Programmmer-X/STELLARIS-DNet
#  * branch            main       -> FETCH_HEAD
# Current branch main is up to date.
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 327 bytes | 327.00 KiB/s, done.
# Total 3 (delta 1), reused 1 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Programmmer-X/STELLARIS-DNet.git
#    ce34327..b2f61e8  main -> main

# %%
#STEP GH_5: TEST CONNECTION 2
with open("test_push.txt", "w") as f:
    f.write("This is a push test")

# %%
#STEP GH_5.1: PUSH TO GITHUB
# !git add .
# !git commit -m "Test push working"
# !git push origin main
# Out:
# [main cd11d86] Test push working
#  1 file changed, 1 insertion(+)
#  create mode 100644 test_push.txt
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 308 bytes | 308.00 KiB/s, done.
# Total 3 (delta 1), reused 1 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Programmmer-X/STELLARIS-DNet.git
#    b2f61e8..cd11d86  main -> main

# %%
#STEP GH_6: Create folders to save colab_git_setup.ipynb in git repo
# !mkdir -p notebooks/setup

# %%
#STEP GH_7: Clean up
# !rm colab_test.txt test_push.txt
# !git add .
# !git commit -m "Cleanup test files"
# !git push
# Out:
# [main b688b7c] Cleanup test files
#  2 files changed, 2 deletions(-)
#  delete mode 100644 colab_test.txt
#  delete mode 100644 test_push.txt
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 238 bytes | 238.00 KiB/s, done.
# Total 2 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Programmmer-X/STELLARIS-DNet.git
#    cd11d86..b688b7c  main -> main

# %%
#STEP GH_8 : Generalization

# %%writefile /content/STELLARIS-DNet/src/git_utils.py

# my function

import os

def setup_git():
    """
    Run this once per Colab session.
    Sets Git identity and enables credential storage.
    """
    os.system('git config --global user.email "your_email@example.com"')
    os.system('git config --global user.name "Your Name"')
    os.system('git config --global credential.helper store')

    print("✅ Git configured. You will be asked for token only once during first push.")


def git_push(commit_msg="update"):
    """
    Adds, commits, and pushes changes to GitHub.
    """
    # Add all changes
    os.system("git add .")

    # Commit
    os.system(f'git commit -m "{commit_msg}"')

    # Push (will ask token only first time)
    os.system("git push origin main")

    print("🚀 Changes pushed to GitHub successfully!")
# Out:
# Overwriting /content/STELLARIS-DNet/src/git_utils.py

# %%
#STEP GH_9 : Push this file
# %cd /content/STELLARIS-DNet
# !git add src/git_utils.py
# !git commit -m "Refactored git_utils to use repo_url"
# !git commit -m "Added status check"
# !git pull --rebase
# !git push
# Out:
# /content/STELLARIS-DNet
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Already up to date.
# Everything up-to-date

# %%
# STEP GH_10: Use in ANY notebook
import sys
sys.path.append("/content/STELLARIS-DNet/src")

from git_utils import setup_git, git_push

setup_git()
# Out:
# ✅ Git configured. You will be asked for token only once during first push.

# %%
git_push("Day 2: Added MLP model")
# Out:
# 🚀 Changes pushed to GitHub successfully!
